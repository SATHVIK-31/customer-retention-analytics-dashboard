# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../processed/customer_features.csv')

df.shape
# Out:
# (3900, 30)

# %%
print(df.columns.tolist())
# Out:
# ['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season', 'Review Rating', 'Subscription Status', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Previous Purchases', 'Payment Method', 'Frequency of Purchases', 'Frequency Score', 'Subscription Score', 'Previous Purchases_N', 'Frequency Score_N', 'Review Rating_N', 'Loyalty Score V1', 'Loyalty Band', 'Promo Dependency Score', 'Promo Dependency Level', 'Customer Value Score', 'Value Tier', 'Customer Segment']

# %%
df.columns = df.columns.str.replace('ï»¿', '', regex=False)

# %%
print(df.columns.tolist())
# Out:
# ['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season', 'Review Rating', 'Subscription Status', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Previous Purchases', 'Payment Method', 'Frequency of Purchases', 'Frequency Score', 'Subscription Score', 'Previous Purchases_N', 'Frequency Score_N', 'Review Rating_N', 'Loyalty Score V1', 'Loyalty Band', 'Promo Dependency Score', 'Promo Dependency Level', 'Customer Value Score', 'Value Tier', 'Customer Segment']

# %%
print("Total Revenue:", df['Purchase Amount (USD)'].sum())
print("Average Purchase:", round(df['Purchase Amount (USD)'].mean(),2))
print("Total Customers:", df['Customer ID'].nunique())
# Out:
# Total Revenue: 233081
# Average Purchase: 59.76
# Total Customers: 3900

# %%
category_revenue = (
    df.groupby('Category')['Purchase Amount (USD)']
      .sum()
      .sort_values(ascending=False)
)

print(category_revenue)
# Out:
# Category
# Clothing       104264
# Accessories     74200
# Footwear        36093
# Outerwear       18524
# Name: Purchase Amount (USD), dtype: int64

# %%
print(df.columns.tolist())
# Out:
# ['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season', 'Review Rating', 'Subscription Status', 'Shipping Type', 'Discount Applied', 'Promo Code Used', 'Previous Purchases', 'Payment Method', 'Frequency of Purchases', 'Frequency Score', 'Subscription Score', 'Previous Purchases_N', 'Frequency Score_N', 'Review Rating_N', 'Loyalty Score V1', 'Loyalty Band', 'Promo Dependency Score', 'Promo Dependency Level', 'Customer Value Score', 'Value Tier', 'Customer Segment']

# %%
df.to_csv('../processed/customer_features.csv', index=False)

# %%
for col in df.columns:
    print(col)
# Out:
# Customer ID
# Age
# Gender
# Item Purchased
# Category
# Purchase Amount (USD)
# Location
# Size
# Color
# Season
# Review Rating
# Subscription Status
# Shipping Type
# Discount Applied
# Promo Code Used
# Previous Purchases
# Payment Method
# Frequency of Purchases
# Frequency Score
# Subscription Score
# Previous Purchases_N
# Frequency Score_N
# Review Rating_N
# Loyalty Score V1
# Loyalty Band
# Promo Dependency Score
# Promo Dependency Level
# Customer Value Score
# Value Tier
# Customer Segment

# %%
df['Customer Segment'].value_counts()
# Out:
# Customer Segment
# Bargain Hunter     1268
# Growth Customer    1073
# VIP Loyalist        975
# Low Engagement      584
# Name: count, dtype: int64

# %%
df['Value Tier'].value_counts()
# Out:
# Value Tier
# Silver      977
# Bronze      975
# Platinum    975
# Gold        973
# Name: count, dtype: int64

# %%
df['Value Tier'].value_counts().plot(
    kind='bar',
    figsize=(8,5)
)

plt.title('Customer Value Tier Distribution')
plt.show()

# %%
df['Promo Dependency Level'].value_counts()
# Out:
# Promo Dependency Level
# Low     2223
# High    1677
# Name: count, dtype: int64

# %%
df['Promo Dependency Level'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title('Promo Dependency Distribution')
plt.show()

# %%
df['Loyalty Band'].value_counts()
# Out:
# Loyalty Band
# Low          693
# Medium       692
# High         692
# Very High    692
# Name: count, dtype: int64

# %%
df['Loyalty Band'].value_counts().plot(
    kind='bar'
)

plt.title('Loyalty Band Distribution')
plt.show()

# %%
df.groupby('Customer Segment')['Purchase Amount (USD)'] \
  .mean() \
  .sort_values(ascending=False)
# Out:
# Customer Segment
# VIP Loyalist       79.657436
# Growth Customer    55.795899
# Bargain Hunter     52.759464
# Low Engagement     49.053082
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby('Customer Segment')['Purchase Amount (USD)'] \
  .mean() \
  .sort_values() \
  .plot(kind='barh')

plt.title('Average Spend by Customer Segment')
plt.show()

# %%
df['Value Tier'].value_counts()
# Out:
# Value Tier
# Silver      977
# Bronze      975
# Platinum    975
# Gold        973
# Name: count, dtype: int64

# %%
df['Promo Dependency Level'].value_counts()
# Out:
# Promo Dependency Level
# Low     2223
# High    1677
# Name: count, dtype: int64

# %%
df['Loyalty Band'].value_counts()
# Out:
# Loyalty Band
# Low          693
# Medium       692
# High         692
# Very High    692
# Name: count, dtype: int64

# %%
df.groupby('Customer Segment')['Purchase Amount (USD)'].mean()
# Out:
# Customer Segment
# Bargain Hunter     52.759464
# Growth Customer    55.795899
# Low Engagement     49.053082
# VIP Loyalist       79.657436
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby('Category')['Purchase Amount (USD)'] \
  .mean() \
  .sort_values(ascending=False)
# Out:
# Category
# Footwear       60.255426
# Clothing       60.025331
# Accessories    59.838710
# Outerwear      57.172840
# Name: Purchase Amount (USD), dtype: float64

# %%
df.groupby('Gender')['Purchase Amount (USD)'] \
  .mean()
# Out:
# Gender
# Female    60.249199
# Male      59.536199
# Name: Purchase Amount (USD), dtype: float64
